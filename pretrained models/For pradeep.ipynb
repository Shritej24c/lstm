# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import keras
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Activation, Dense
from keras.layers import Dropout
from keras.models import load_model

# %%
data= pd.read_csv('Train-data.csv')
target= data.values[:, 1]
info=data.values[3:,0]/10000
info=np.array(info,dtype=float)
info.shape
target=np.array(target,dtype=float)
val=[[ [target[j + i]/10000 for i in range(3)]]for j in range(73905)]
val=np.array(val,dtype=float)
val=np.reshape(val,(73905,3,1))
val.shape
x_train,x_test,y_train,y_test=train_test_split(val,info,test_size=0.2,random_state=40)

model=Sequential()
model.add(LSTM((4),batch_input_shape=(None,3,1),return_sequences=True))
model.add(LSTM((8),return_sequences=False))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam',metrics=['mae','mse'])
model.summary()
history=model.fit(x_train,y_train,epochs=1000,validation_data=(x_test,y_test))

# %%
//To test above model

# %%
test=pd.read_csv('testRNN1.csv')
test=test.values[:,0]
t=test

# %%
test.shape

# %%
test=np.array(test,dtype=float)

# %%
test=[[ [test[j + i]/10000 for i in range(3)]]for j in range(76)]

# %%
test
test=np.array(test,dtype=float)
test.shape

# %%
test=np.reshape(test,(76,3,1))
test.shape

# %%
Y_test = model.predict(test)*10000

# %%
Y_test

# %%
plt.plot(Y_test)
plt.plot(t)
